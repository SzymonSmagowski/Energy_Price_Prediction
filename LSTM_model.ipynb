# %%
# The plan for the model is as follows:
# 1. Add to dataset information about demand on polish market (how much energy people need, I do not know if it will be available).
# 2. Add other data sources with energy produced every hour.
# 3. It will create some sort of price evaluation.
# 4. Add variables like temperature - higher prices in the winter.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from time import *
import tensorflow as tf
# Out:
# WARNING:tensorflow:From c:\Users\szymo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
dir_csv = "ML_Intern_data.csv"
df = pd.read_csv(dir_csv)
df.head()
# Out:
#                              date  da1_price
# 0  2021-01-01 00:00:00.000000 UTC     176.49
# 1  2021-01-01 01:00:00.000000 UTC     170.80
# 2  2021-01-01 02:00:00.000000 UTC     160.00
# 3  2021-01-01 03:00:00.000000 UTC     148.00
# 4  2021-01-01 04:00:00.000000 UTC     140.58

# %%
df = df.set_index('date')
df.index = pd.to_datetime(df.index)

# %%
# due to weird prices in previous year, let's work only 1 year prior (or a little more) to current day
df_one_year = df.loc[(df.index >= '2022-11-22 00:00:00+00:00')]
fig = plt.figure(1, (15,7))
ax = plt.axes()

ax.plot(df_one_year.index, df_one_year['da1_price'])

# %%
df
# Out:
#                            da1_price
# date
# 2021-01-01 00:00:00+00:00     176.49
# 2021-01-01 01:00:00+00:00     170.80
# 2021-01-01 02:00:00+00:00     160.00
# 2021-01-01 03:00:00+00:00     148.00
# 2021-01-01 04:00:00+00:00     140.58
# ...                              ...
# 2023-11-23 19:00:00+00:00     374.00
# 2023-11-23 20:00:00+00:00     329.00
# 2023-11-23 21:00:00+00:00     250.00
# 2023-11-23 22:00:00+00:00     225.00
# 2023-11-23 23:00:00+00:00     197.70
#
# [25368 rows x 1 columns]
